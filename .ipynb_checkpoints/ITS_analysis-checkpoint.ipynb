# %%
import seaborn as sb
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

DATA = Path('F:\Scans_guineapig\ITS')

# %%
ITS_lat = pd.read_csv(DATA / 'LAT'/ 'result.txt', sep = '\t', header = None)
ITS_lat.columns = ['Filename','BV_TV', 'pBV_TV', 'rBV_TV', 'aBV_TV', 'pBV_BV', 'rBV_BV', 'pTb.N', 'rTb.N', 'pTb.Th',
                   'rTb.Th', 'pTb.S', 'rTb.l', 'RR_junc', 'PR_junc', 'PP junc','NA']
#ITS_lat.drop(columns=['NA'])

# %%
ITS_lat['PR_ratio'] = ITS_lat.apply(
    lambda row:(row.pBV_TV)/(row.rBV_TV), axis=1)

# %%
ITS_lat['ID'] = ITS_lat['Filename'].astype(str).str.split('_').str[0]
ITS_lat['Location'] = ITS_lat['Filename'].astype(str).str.split('_').str[1]
ITS_lat['Subregion'] = ITS_lat['Filename'].astype(str).str.split('_').str[2]
ITS_lat.head()
# Out:
#                     Filename    BV_TV   pBV_TV   rBV_TV   aBV_TV   pBV_BV  \
# 0  E0016710_LT_LAT_ITS_230;1  0.38504  0.25068  0.13436  0.15456  0.65104
# 1  E0016769_LT_LAT_ITS_230;1  0.46495  0.35773  0.10722  0.21948  0.76939
# 2  E0016710_LF_LAT_ITS_230;1  0.35108  0.23316  0.11792  0.16910  0.66414
# 3  E0016769_LF_LAT_ITS_230;1  0.36746  0.25865  0.10881  0.17332  0.70388
# 4  E0016710_RT_LAT_ITS_230;1  0.36171  0.21309  0.14862  0.14855  0.58911
#
#     rBV_BV    pTb.N    rTb.N   pTb.Th  ...    pTb.S    rTb.l   RR_junc  \
# 0  0.34896  3.55897  3.61119  0.11153  ...  0.04987  0.36004  24.85161
# 1  0.23061  3.62655  3.29107  0.12727  ...  0.05901  0.35676  16.64320
# 2  0.33586  3.52373  3.36623  0.10863  ...  0.04907  0.36384  17.09921
# 3  0.29612  3.61226  3.23184  0.11036  ...  0.04974  0.35814  14.56964
# 4  0.41089  3.52240  3.66502  0.10661  ...  0.04574  0.35913  26.79659
#
#     PR_junc   PP junc  NA  PR_ratio        ID Location Subregion
# 0  68.64077  58.22826 NaN  1.865734  E0016710       LT       LAT
# 1  56.37925  52.50947 NaN  3.336411  E0016769       LT       LAT
# 2  62.71365  54.20127 NaN  1.977273  E0016710       LF       LAT
# 3  59.24656  54.35692 NaN  2.377079  E0016769       LF       LAT
# 4  70.42739  59.22882 NaN  1.433791  E0016710       RT       LAT
#
# [5 rows x 21 columns]

# %%
ITS_med = pd.read_csv(DATA / 'MED'/'result.txt', sep = '\t', header = None)
ITS_med.columns = ['Filename','BV_TV', 'pBV_TV', 'rBV_TV', 'aBV_TV', 'pBV_BV', 'rBV_BV', 'pTb.N', 'rTb.N', 'pTb.Th',
                   'rTb.Th', 'pTb.S', 'rTb.l', 'RR_junc', 'PR_junc', 'PP junc','NA']

# %%
ITS_med['PR_ratio'] = ITS_med.apply(
    lambda row:(row.pBV_TV)/(row.rBV_TV), axis=1)

# %%
ITS_med['ID'] = ITS_med['Filename'].astype(str).str.split('_').str[0]
ITS_med['Location'] = ITS_med['Filename'].astype(str).str.split('_').str[1]
ITS_med['Subregion'] = ITS_med['Filename'].astype(str).str.split('_').str[2]
ITS_med.head()
# Out:
#                     Filename    BV_TV   pBV_TV   rBV_TV   aBV_TV   pBV_BV  \
# 0  E0016710_LT_MED_ITS_230;1  0.38557  0.26305  0.12252  0.16401  0.68224
# 1  E0016769_LT_MED_ITS_230;1  0.42290  0.32004  0.10286  0.19249  0.75677
# 2  E0016710_LF_MED_ITS_230;1  0.39482  0.28011  0.11472  0.18827  0.70944
# 3  E0016769_LF_MED_ITS_230;1  0.39801  0.29842  0.09959  0.19702  0.74977
# 4  E0016710_RT_MED_ITS_230;1  0.45047  0.31290  0.13757  0.19884  0.69461
#
#     rBV_BV    pTb.N    rTb.N   pTb.Th  ...    pTb.S    rTb.l   RR_junc  \
# 0  0.31776  3.63384  3.51517  0.11059  ...  0.04958  0.36572  21.25821
# 1  0.24323  3.65267  3.21976  0.12029  ...  0.05461  0.36230  13.82393
# 2  0.29056  3.55218  3.28990  0.11740  ...  0.05324  0.35855  16.28924
# 3  0.25023  3.58223  3.17622  0.11742  ...  0.05529  0.36031  13.34431
# 4  0.30539  3.74748  3.59690  0.11431  ...  0.05205  0.36267  23.39748
#
#     PR_junc   PP junc  NA  PR_ratio        ID Location Subregion
# 0  68.58617  59.92542 NaN  2.146996  E0016710       LT       MED
# 1  57.65803  52.88965 NaN  3.111414  E0016769       LT       MED
# 2  57.39622  53.49511 NaN  2.441684  E0016710       LF       MED
# 3  54.78845  52.79614 NaN  2.996486  E0016769       LF       MED
# 4  74.01640  66.62772 NaN  2.274478  E0016710       RT       MED
#
# [5 rows x 21 columns]

# %%
ITS_merge = pd.concat([ITS_med,ITS_lat])
ITS_merge.shape
# Out:
# (134, 21)

# %%
GP_ID = pd.read_csv(DATA /'GP_fileID.txt', header = None, sep = '\t')
GP_ID.columns = ['GP','Month', 'ID']
GP_ID.head()
# Out:
#       GP  Month        ID
# 0   GP_9      2  E0016709
# 1  GP_10      2  E0016710
# 2  GP_11      2  E0016711
# 3  GP_12      2  E0016712
# 4   GP_9      3  E0016770

# %%
ITS_merge = pd.merge(ITS_merge, GP_ID, left_on = 'ID', right_on = 'ID')
ITS_merge.head(10)
# Out:
#                     Filename    BV_TV   pBV_TV   rBV_TV   aBV_TV   pBV_BV  \
# 0  E0016710_LT_MED_ITS_230;1  0.38557  0.26305  0.12252  0.16401  0.68224
# 1  E0016710_LF_MED_ITS_230;1  0.39482  0.28011  0.11472  0.18827  0.70944
# 2  E0016710_RT_MED_ITS_230;1  0.45047  0.31290  0.13757  0.19884  0.69461
# 3  E0016710_RF_MED_ITS_230;1  0.40576  0.31113  0.09463  0.22196  0.76679
# 4  E0016710_LT_LAT_ITS_230;1  0.38504  0.25068  0.13436  0.15456  0.65104
# 5  E0016710_LF_LAT_ITS_230;1  0.35108  0.23316  0.11792  0.16910  0.66414
# 6  E0016710_RT_LAT_ITS_230;1  0.36171  0.21309  0.14862  0.14855  0.58911
# 7  E0016710_RF_LAT_ITS_230;1  0.32741  0.21653  0.11087  0.16248  0.66136
# 8  E0016769_LT_MED_ITS_230;1  0.42290  0.32004  0.10286  0.19249  0.75677
# 9  E0016769_LF_MED_ITS_230;1  0.39801  0.29842  0.09959  0.19702  0.74977
#
#     rBV_BV    pTb.N    rTb.N   pTb.Th  ...   RR_junc   PR_junc   PP junc  NA  \
# 0  0.31776  3.63384  3.51517  0.11059  ...  21.25821  68.58617  59.92542 NaN
# 1  0.29056  3.55218  3.28990  0.11740  ...  16.28924  57.39622  53.49511 NaN
# 2  0.30539  3.74748  3.59690  0.11431  ...  23.39748  74.01640  66.62772 NaN
# 3  0.23321  3.56004  3.07473  0.11969  ...  11.58324  51.79361  49.55970 NaN
# 4  0.34896  3.55897  3.61119  0.11153  ...  24.85161  68.64077  58.22826 NaN
# 5  0.33586  3.52373  3.36623  0.10863  ...  17.09921  62.71365  54.20127 NaN
# 6  0.41089  3.52240  3.66502  0.10661  ...  26.79659  70.42739  59.22882 NaN
# 7  0.33864  3.48249  3.30710  0.10779  ...  17.87338  55.65856  51.28344 NaN
# 8  0.24323  3.65267  3.21976  0.12029  ...  13.82393  57.65803  52.88965 NaN
# 9  0.25023  3.58223  3.17622  0.11742  ...  13.34431  54.78845  52.79614 NaN
#
#    PR_ratio        ID  Location  Subregion     GP Month
# 0  2.146996  E0016710        LT        MED  GP_10     2
# 1  2.441684  E0016710        LF        MED  GP_10     2
# 2  2.274478  E0016710        RT        MED  GP_10     2
# 3  3.287858  E0016710        RF        MED  GP_10     2
# 4  1.865734  E0016710        LT        LAT  GP_10     2
# 5  1.977273  E0016710        LF        LAT  GP_10     2
# 6  1.433791  E0016710        RT        LAT  GP_10     2
# 7  1.953008  E0016710        RF        LAT  GP_10     2
# 8  3.111414  E0016769        LT        MED  GP_10     3
# 9  2.996486  E0016769        LF        MED  GP_10     3
#
# [10 rows x 23 columns]

# %%
ITS_BV_TV = ITS_merge.groupby(['Location','Subregion','Month'])['BV_TV'].mean().unstack(level=2)
ITS_BV_TV
# Out:
# Month                      2         3         4
# Location Subregion
# LF       LAT        0.339338  0.352407  0.358023
#          MED        0.389018  0.407882  0.416517
# LT       LAT        0.342207  0.398887  0.411987
#          MED        0.365943  0.440682  0.479067
# RF       LAT        0.337444  0.376498  0.354473
#          MED        0.377628  0.419680  0.420880
# RT       LAT        0.358958  0.414477  0.426260
#          MED        0.397596  0.449830  0.519687

# %%
ITS_BV_TV_err = ITS_merge.groupby(['Location','Subregion','Month'])['BV_TV'].std().unstack(level=2)
ITS_BV_TV_err
# Out:
# Month                      2         3         4
# Location Subregion
# LF       LAT        0.026390  0.045245  0.021703
#          MED        0.017130  0.030634  0.026411
# LT       LAT        0.033033  0.058331  0.064817
#          MED        0.037024  0.040803  0.063925
# RF       LAT        0.030688  0.021662  0.007606
#          MED        0.021808  0.023316  0.046549
# RT       LAT        0.019217  0.039887  0.048931
#          MED        0.053831  0.036348  0.071625

# %%
ITS_BV_TV.plot(kind='bar', yerr= ITS_BV_TV_err, capsize=3, title='BV/TV').get_figure().savefig('ITS_BV_TV.png', dpi=1200, bbox_inches="tight")

# %%
ITS_PR_ratio = ITS_merge.groupby(['Location','Subregion','Month'])['PR_ratio'].mean().unstack(level=2)
ITS_PR_ratio
# Out:
# Month                      2         3         4
# Location Subregion
# LF       LAT        1.721404  2.297805  2.111459
#          MED        2.340954  3.270262  2.904700
# LT       LAT        1.234097  2.276006  2.577586
#          MED        1.611762  2.981778  4.153143
# RF       LAT        1.450281  2.095582  1.838972
#          MED        2.262366  2.753710  2.456825
# RT       LAT        1.376750  2.397421  2.207678
#          MED        1.627715  3.021514  3.092576

# %%
ITS_PR_ratio_err = ITS_merge.groupby(['Location','Subregion','Month'])['PR_ratio'].std().unstack(level=2)
ITS_PR_ratio_err
# Out:
# Month                      2         3         4
# Location Subregion
# LF       LAT        0.674535  1.171053  0.360190
#          MED        0.585607  1.129206  0.115390
# LT       LAT        0.528300  0.896824  1.047565
#          MED        0.390090  0.247910  1.130655
# RF       LAT        0.414652  0.352064  0.267249
#          MED        1.004012  0.998325  0.547636
# RT       LAT        0.377963  0.851781  0.691487
#          MED        0.645417  1.219956  0.664402

# %%
plt.style.use('dark_background')
#plt.style.use('tableau-colorblind10')
plt.style.use('seaborn-bright')

# %%
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams.update({'font.size': 22})

# %%
ITS_PR_ratio.plot(kind='bar', yerr= ITS_PR_ratio_err, capsize=3, title='PR Ratio').get_figure().savefig('ITS_PR_ratio.png', dpi=1200, bbox_inches="tight")
