# %% [markdown]
# # Import Python libraries and directory of results

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import pingouin as pg
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scikit_posthocs as sp
from statsmodels.formula.api import ols
from statannotations.Annotator import Annotator
#from ITS_lib.ITS_functions import ITS_plot, ITS_subplots

# %%
#from google.colab import drive
#drive.mount("/content/drive")

#!pip install pingouin

#!pip install statannotations
#!pip install statsmodels
#!pip install scikit_posthocs

# %%
from pathlib import Path

#DATA = Path("/content/drive/My Drive/BBL/GP_ITS")
DATA = Path("C:/Users/Teo/Downloads")

# %% [markdown]
# # Create one table with LAT and MED results

# %%
ITS_lat = pd.read_csv(DATA / 'result_GP_LAT.txt', sep = '\t', header = None)
ITS_lat.columns = ['Filename','BV_TV', 'pBV_TV', 'rBV_TV', 'aBV_TV', 'pBV_BV', 'rBV_BV', 'pTb.N', 'rTb.N', 'pTb.Th',
                   'rTb.Th', 'pTb.S', 'rTb.l', 'RR_junc', 'PR_junc', 'PP junc','NA']

# %%
ITS_lat['PR_ratio'] = ITS_lat.apply(
    lambda row:(row.pBV_TV)/(row.rBV_TV), axis=1)

# %%
ITS_lat['ID'] = ITS_lat['Filename'].astype(str).str.split('_').str[0]
ITS_lat['Location'] = ITS_lat['Filename'].astype(str).str.split('_').str[1]
ITS_lat['Subregion'] = ITS_lat['Filename'].astype(str).str.split('_').str[2]

# %%
ITS_med = pd.read_csv(DATA / 'result_GP_MED.txt', sep = '\t', header = None)
ITS_med.columns = ['Filename','BV_TV', 'pBV_TV', 'rBV_TV', 'aBV_TV', 'pBV_BV', 'rBV_BV', 'pTb.N', 'rTb.N', 'pTb.Th',
                   'rTb.Th', 'pTb.S', 'rTb.l', 'RR_junc', 'PR_junc', 'PP junc','NA']

# %%
ITS_med['PR_ratio'] = ITS_med.apply(
    lambda row:(row.pBV_TV)/(row.rBV_TV), axis=1)

# %%
ITS_med['ID'] = ITS_med['Filename'].astype(str).str.split('_').str[0]
ITS_med['Location'] = ITS_med['Filename'].astype(str).str.split('_').str[1]
ITS_med['Subregion'] = ITS_med['Filename'].astype(str).str.split('_').str[2]

# %%
ITS_merge = pd.concat([ITS_med,ITS_lat])

# %%
GP_ID = pd.read_csv(DATA /'GP_fileID.txt', header = None, sep = '\t')
GP_ID.columns = ['GP','Month', 'ID','Location']

# %%
ITS_merge = pd.merge(ITS_merge, GP_ID, left_on = 'ID', right_on = 'ID')

# %%
#ITS_merge[(ITS_merge.Location == ['LF'] | ITS_merge.Location == ['LT']), 'Left/Right'] = 'Left'
#ITS_merge["Left/Right"] = ITS_merge.Location.where((ITS_merge.Location == ['LF']) , "Left")

# %%
ITS_merge.head()

# %% [markdown]
# # Create one table with ITS results

# %%
ITS = pd.read_csv(DATA / 'result_gp_longitudinal_erode.txt', sep = '\t', header = None)
ITS.columns = ['Filename','BV_TV', 'pBV_TV', 'rBV_TV', 'aBV_TV', 'pBV_BV', 'rBV_BV', 'pTb_N', 'rTb_N', 'pTb_Th',
                   'rTb_Th', 'pTb_S', 'rTb_l', 'RR_junc', 'PR_junc', 'PP junc']
ITS['PR_ratio'] = ITS.apply(
    lambda row:(row.pBV_TV)/(row.rBV_TV), axis=1)
ITS['PR_num_ratio'] = ITS.apply(
    lambda row:(row.pTb_N)/(row.rTb_N), axis=1)
ITS['ID'] = ITS['Filename'].astype(str).str.split('_').str[0]
ITS['Location'] = ITS['Filename'].astype(str).str.split('_').str[1]
ITS['Subregion'] = ITS['Filename'].astype(str).str.split('_').str[2]
ITS['Location_Subregion'] = ITS['Location'] + '_' + ITS['Subregion']
ITS.head()
# Out:
#                 Filename    BV_TV   pBV_TV   rBV_TV   aBV_TV   pBV_BV  \
# 0  E0016708_LF_LAT_ITS;1  0.28443  0.14333  0.14110  0.11553  0.50392
# 1  E0016708_LF_MED_ITS;1  0.34058  0.21124  0.12934  0.15267  0.62024
# 2  E0016708_LT_LAT_ITS;1  0.31984  0.16814  0.15170  0.12054  0.52570
# 3  E0016708_LT_MED_ITS;1  0.36423  0.21199  0.15223  0.12385  0.58204
# 4  E0016708_RF_LAT_ITS;1  0.28139  0.13513  0.14626  0.11004  0.48023
#
#     rBV_BV    pTb_N    rTb_N   pTb_Th  ...    rTb_l   RR_junc   PR_junc  \
# 0  0.49608  3.18258  3.69329  0.09978  ...  0.36209  29.37657  63.02933
# 1  0.37976  3.47862  3.52558  0.10721  ...  0.35681  23.13486  64.18883
# 2  0.47430  3.35284  3.81937  0.10205  ...  0.36523  29.19542  72.04979
# 3  0.41796  3.50350  3.84579  0.10753  ...  0.35573  33.07125  75.85184
# 4  0.51977  3.17381  3.78175  0.10055  ...  0.35089  33.77932  64.49830
#
#     PP junc  PR_ratio  PR_num_ratio        ID  Location Subregion  \
# 0  46.63310  1.015804      0.861719  E0016708        LF       LAT
# 1  54.73330  1.633215      0.986680  E0016708        LF       MED
# 2  55.57456  1.108372      0.877852  E0016708        LT       LAT
# 3  60.33923  1.392564      0.910996  E0016708        LT       MED
# 4  47.42579  0.923903      0.839244  E0016708        RF       LAT
#
#   Location_Subregion
# 0             LF_LAT
# 1             LF_MED
# 2             LT_LAT
# 3             LT_MED
# 4             RF_LAT
#
# [5 rows x 22 columns]

# %%
GP_ID = pd.read_csv(DATA /'GP_fileID.txt', header = None, sep = '\t')
GP_ID.columns = ['GP','Month', 'ID','Location']

# %%
ITS_merge = pd.merge(ITS, GP_ID, left_on = 'ID', right_on = 'ID')
ITS_merge.head()
# Out:
#                 Filename    BV_TV   pBV_TV   rBV_TV   aBV_TV   pBV_BV  \
# 0  E0016708_LF_LAT_ITS;1  0.28443  0.14333  0.14110  0.11553  0.50392
# 1  E0016708_LF_MED_ITS;1  0.34058  0.21124  0.12934  0.15267  0.62024
# 2  E0016708_LT_LAT_ITS;1  0.31984  0.16814  0.15170  0.12054  0.52570
# 3  E0016708_LT_MED_ITS;1  0.36423  0.21199  0.15223  0.12385  0.58204
# 4  E0016708_RF_LAT_ITS;1  0.28139  0.13513  0.14626  0.11004  0.48023
#
#     rBV_BV    pTb_N    rTb_N   pTb_Th  ...   PP junc  PR_ratio  PR_num_ratio  \
# 0  0.49608  3.18258  3.69329  0.09978  ...  46.63310  1.015804      0.861719
#                    5      0.003048  0.009136   0.098401  17.886825  20.145819
# LT_LAT             2      0.003541  0.006305   6.469034  10.041571   9.377099
#                    3      0.004685  0.005938   7.316364   8.397624  11.831868
#                    4      0.002968  0.004775   4.286855   8.424718   6.574892
# LT_MED             2      0.001791  0.005065   5.382629   9.673256   7.955671
#                    3      0.003851  0.007929   2.553993   9.546642   8.656002
#                    4      0.005541  0.007198  12.784473  27.562863  15.276149
# RF_LAT             2      0.002919  0.004245   6.604722   9.081690   6.648245
#                    3      0.005979  0.010197  18.811651  24.236979  10.462369
#                    4      0.006044  0.007132   7.118555   8.604563   3.048525
#                    5      0.002072  0.006350   0.442755   2.004315   0.339227
# RF_MED             2      0.003387  0.004820   7.280085   7.464798   4.319963
#                    3      0.006731  0.007852  14.726886  31.577412  16.225232
#                    4      0.004524  0.007753   5.987330   8.686414   2.997151
#                    5      0.006879  0.007914   3.070981   3.140093   3.941401
# RT_LAT             2      0.002388  0.004795   6.418397   5.632869   6.475437
#                    3      0.005437  0.007073   8.036108   9.627986   5.536544
#                    4      0.002847  0.005754   5.202398   7.894600   6.541140
#                    5      0.001614  0.012254   2.477699   3.823398   1.149954
# RT_MED             2      0.003692  0.004340   7.963612  11.924779   9.004887
#                    3      0.004068  0.006798  15.508764  23.982402  12.363983
#                    4      0.002137  0.005709   5.917066  13.451423   9.441508
#                    5      0.003534  0.007624   2.924524   9.776005   8.498987
#
#                           PR_ratio  PR_num_ratio
# Location_Subregion Month
# LF_LAT             2      0.428968      0.092601
#                    3      0.740190      0.100587
#                    4      0.420314      0.060546
#                    5           NaN           NaN
# LF_MED             2      0.388498      0.080514
#                    3      0.953496      0.114566
#                    4      0.317625      0.040275
#                    5      1.237141      0.081471
# LT_LAT             2      0.238929      0.060677
#                    3      0.826452      0.139631
#                    4      0.796737      0.094089
# LT_MED             2      0.233447      0.058828
#                    3      0.577116      0.080165
#                    4      1.207970      0.136601
# RF_LAT             2      0.305565      0.070621
#                    3      0.901786      0.161040
#                    4      1.320673      0.157851
#                    5      0.372385      0.002903
# RF_MED             2      0.524802      0.092977
#                    3      0.801769      0.131025
#                    4      1.336216      0.129512
#                    5      0.863930      0.066707
# RT_LAT             2      0.293900      0.079753
#                    3      0.672366      0.107343
#                    4      0.712058      0.112620
#                    5      1.153094      0.087555
# RT_MED             2      0.482224      0.094172
#                    3      0.617947      0.116705
#                    4      0.458560      0.089973
#                    5      0.329226      0.026823

# %% [markdown]
# ### Add code to save merged dataframe and can start with that

# %% [markdown]
# ## Filter by individual GP

# %%
def label_cohort (row):
    if ((row['GP'] == 'GP_10') or (row['GP'] == 'GP_11') or (row['GP'] == 'GP_12')):
        return 5
    elif ((row['GP'] == 'GP_9') or (row['GP'] == 'GP_13') or (row['GP'] == 'GP_14') or (row['GP'] == 'GP_15')):
        return 4
    elif ((row['GP'] == 'GP_8')  or (row['GP'] == 'GP_16') or (row['GP'] == 'GP_17')):
        return 3
    else:
        return 0

# %%
ITS_merge['Cohort'] = ITS_merge.apply(lambda row: label_cohort(row), axis=1)

# %%
ITS_erode_RT_MED.groupby(['Cohort', 'Month']).mean()
# Out:
#                  BV_TV    pBV_TV    rBV_TV    aBV_TV    pBV_BV    rBV_BV  \
# Cohort Month
# 3      2      0.317390  0.147440  0.169947  0.126193  0.463227  0.536773
#        3      0.404260  0.275483  0.128773  0.158077  0.681110  0.318890
# 4      2      0.335597  0.179507  0.156097  0.143870  0.533710  0.466290
#        3      0.427757  0.262050  0.165703  0.174597  0.612263  0.387737
#        4      0.467670  0.337093  0.130583  0.183887  0.721277  0.278723
# 5      2      0.378123  0.214393  0.163730  0.154503  0.555430  0.444570
#        3      0.422520  0.252233  0.170290  0.168657  0.592737  0.407263
#        4      0.480343  0.333337  0.147000  0.207923  0.693347  0.306653
#        5      0.458937  0.339100  0.119837  0.203050  0.740017  0.259983
#
#                  pTb_N     rTb_N    pTb_Th    rTb_Th     pTb_S     rTb_l  \
# Cohort Month
# 3      2      3.231967  3.911837  0.101543  0.096103  0.042787  0.357793
#        3      3.706467  3.506130  0.111153  0.097330  0.048600  0.360997
# 4      2      3.357137  3.814643  0.104030  0.095643  0.045417  0.355767
#        3      3.636130  3.835593  0.115140  0.096167  0.047050  0.357310
#        4      3.871257  3.453103  0.115343  0.096417  0.050373  0.360797
# 5      2      3.524697  3.803557  0.105010  0.098493  0.045007  0.353227
#        3      3.715420  4.006083  0.109210  0.093053  0.044460  0.354233
#        4      3.794083  3.722087  0.120320  0.095620  0.050613  0.353217
#        5      3.765047  3.213167  0.118107  0.095690  0.053933  0.362683
#
#                 RR_junc     PR_junc    PP junc  PR_ratio  PR_num_ratio
# Cohort Month
# 3      2      34.687870   75.902763  52.236780  0.873947      0.827856
#        3      18.850270   72.961253  63.781680  2.185964      1.061414
# 4      2      30.024917   69.591113  51.731933  1.191732      0.883797
#        3      28.863077   81.833643  62.057110  1.722349      0.957364
#        4      15.931560   74.862797  68.053990  2.656158      1.128458
# 5      2      28.309230   74.251267  58.047120  1.377753      0.930953
#        3      32.519187  100.918683  77.037050  1.546402      0.938282
#        4      23.212447   78.126800  66.162873  2.263978      1.019390
#        5      13.065517   60.325203  57.672807  2.865285      1.172436

# %% [markdown]
# We want to show that there is no difference (p>0.05-0.99) between the three cohorts and that if we continued to scan the 3 and 4 month old guinea pigs, they would have had similar trends as the 5 month old guinea pigs. Then, we can run the linear mixed effects model to compare between time points, even though there are different number of animals in each group.

# %%
import scipy.stats as stats

stats.f_oneway(ITS_erode_RT_MED['BV_TV'][ITS_erode_RT_MED['Cohort'] == 3],
               ITS_erode_RT_MED['BV_TV'][ITS_erode_RT_MED['Cohort'] == 4],
               ITS_erode_RT_MED['BV_TV'][ITS_erode_RT_MED['Cohort'] == 5])
# Out:
# F_onewayResult(statistic=3.0980551574582766, pvalue=0.06355106909318659)

# %%
stats.f_oneway(ITS_erode_RT_MED['PR_ratio'][ITS_erode_RT_MED['Cohort'] == 3],
               ITS_erode_RT_MED['PR_ratio'][ITS_erode_RT_MED['Cohort'] == 4],
               ITS_erode_RT_MED['PR_ratio'][ITS_erode_RT_MED['Cohort'] == 5])
# Out:
# F_onewayResult(statistic=0.7468420980888183, pvalue=0.48455567077438455)

# %%
stats.f_oneway(ITS_erode_RT_MED['PR_num_ratio'][ITS_erode_RT_MED['Cohort'] == 3],
               ITS_erode_RT_MED['PR_num_ratio'][ITS_erode_RT_MED['Cohort'] == 4],
               ITS_erode_RT_MED['PR_num_ratio'][ITS_erode_RT_MED['Cohort'] == 5])
# Out:
# F_onewayResult(statistic=0.5311618455290967, pvalue=0.5946739070331517)

# %%
stats.f_oneway(ITS_erode_RT_MED['pBV_TV'][ITS_erode_RT_MED['Cohort'] == 3],
               ITS_erode_RT_MED['pBV_TV'][ITS_erode_RT_MED['Cohort'] == 4],
               ITS_erode_RT_MED['pBV_TV'][ITS_erode_RT_MED['Cohort'] == 5])
# Out:
# F_onewayResult(statistic=1.963550247305511, pvalue=0.16226495240311178)

# %%
stats.f_oneway(ITS_erode_RT_MED['rBV_TV'][ITS_erode_RT_MED['Cohort'] == 3],
               ITS_erode_RT_MED['rBV_TV'][ITS_erode_RT_MED['Cohort'] == 4],
               ITS_erode_RT_MED['rBV_TV'][ITS_erode_RT_MED['Cohort'] == 5])
# Out:
# F_onewayResult(statistic=0.003979936043641187, pvalue=0.9960286306341383)

# %%
stats.f_oneway(ITS_erode_RT_MED['pTb_N'][ITS_erode_RT_MED['Cohort'] == 3],
               ITS_erode_RT_MED['pTb_N'][ITS_erode_RT_MED['Cohort'] == 4],
               ITS_erode_RT_MED['pTb_N'][ITS_erode_RT_MED['Cohort'] == 5])
# Out:
# F_onewayResult(statistic=1.774924320332785, pvalue=0.19103119589294223)

# %%
stats.f_oneway(ITS_erode_RT_MED['rTb_N'][ITS_erode_RT_MED['Cohort'] == 3],
               ITS_erode_RT_MED['rTb_N'][ITS_erode_RT_MED['Cohort'] == 4],
               ITS_erode_RT_MED['rTb_N'][ITS_erode_RT_MED['Cohort'] == 5])
# Out:
# F_onewayResult(statistic=0.008463599429415236, pvalue=0.991575074143963)

# %%
stats.f_oneway(ITS_erode_RT_MED['pTb_Th'][ITS_erode_RT_MED['Cohort'] == 3],
               ITS_erode_RT_MED['pTb_Th'][ITS_erode_RT_MED['Cohort'] == 4],
               ITS_erode_RT_MED['pTb_Th'][ITS_erode_RT_MED['Cohort'] == 5])
# Out:
# F_onewayResult(statistic=2.180170442081718, pvalue=0.13489552437936436)

# %%
stats.f_oneway(ITS_erode_RT_MED['rTb_Th'][ITS_erode_RT_MED['Cohort'] == 3],
               ITS_erode_RT_MED['rTb_Th'][ITS_erode_RT_MED['Cohort'] == 4],
               ITS_erode_RT_MED['rTb_Th'][ITS_erode_RT_MED['Cohort'] == 5])
# Out:
# F_onewayResult(statistic=0.08138418437173313, pvalue=0.9220927615408693)

# %% [markdown]
# ## Linear mixed effect model for statistical analysis

# %%
model = smf.mixedlm(("BV_TV ~ Month"), ITS_erode_RT_MED, groups=ITS_erode_RT_MED["GP"]) #, reformula="~Month")
mdf = model.fit(method=["bfgs"])
print(mdf.summary())
# Out:
#         Mixed Linear Model Regression Results
# =====================================================
# Model:            MixedLM Dependent Variable: BV_TV
# No. Observations: 27      Method:             REML
# No. Groups:       9       Scale:              0.0019
# Min. group size:  2       Log-Likelihood:     39.8581
# Max. group size:  4       Converged:          Yes
# Mean group size:  3.0
# -----------------------------------------------------
#              Coef. Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------
# Intercept    0.262    0.029 9.153 0.000  0.206  0.318
# Month        0.048    0.009 5.227 0.000  0.030  0.066
# Group Var    0.000    0.017
# =====================================================
# D:\Anaconda3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)

# %%
model = smf.mixedlm(("PR_ratio ~ Month"), ITS_erode_RT_MED, groups=ITS_erode_RT_MED["GP"])
mdf = model.fit(method=["bfgs"])
print(mdf.summary())
# Out:
#         Mixed Linear Model Regression Results
# ======================================================
# Model:            MixedLM Dependent Variable: PR_ratio
# No. Observations: 27      Method:             REML
# No. Groups:       9       Scale:              0.2350
# Min. group size:  2       Log-Likelihood:     -21.4338
# Max. group size:  4       Converged:          Yes
# Mean group size:  3.0
# ------------------------------------------------------
#             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------
# Intercept   -0.031    0.313 -0.099 0.921 -0.645  0.583
# Month        0.607    0.096  6.328 0.000  0.419  0.795
# Group Var    0.017    0.112
# ======================================================

# %%
model = smf.mixedlm(("pBV_TV ~ Month"), ITS_erode_RT_MED, groups=ITS_erode_RT_MED["GP"]) #, reformula="~Month")
mdf = model.fit(method=["bfgs"])
print(mdf.summary())
# Out:
#         Mixed Linear Model Regression Results
# =====================================================
# Model:            MixedLM Dependent Variable: pBV_TV
# No. Observations: 27      Method:             REML
# No. Groups:       9       Scale:              0.0021
# Min. group size:  2       Log-Likelihood:     38.4740
# Max. group size:  4       Converged:          No
# Mean group size:  3.0
# -----------------------------------------------------
#              Coef. Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------
# Intercept    0.069    0.029 2.393 0.017  0.012  0.125
# Month        0.062    0.009 7.071 0.000  0.044  0.079
# Group Var    0.000
# =====================================================
# D:\Anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# D:\Anaconda3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# D:\Anaconda3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 0.002366
#   warnings.warn(msg, ConvergenceWarning)
# D:\Anaconda3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# D:\Anaconda3\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)

# %% [markdown]
# # Cartilage thickness

# %%
GP_measurements = pd.read_csv(DATA /'gp_measurements.txt', header = None, sep = '\t')
GP_measurements.columns = ['GP','Sample','ID']

# %%
GP_cartilage_thickness= pd.read_csv(DATA /'gp_cartilage_thickness.txt', header = None, sep = '\t')
GP_cartilage_thickness.columns = ['Sample','Cart_LAT_thickness','Cart_MED_thickness']

# %%
GP_merge = pd.merge(GP_cartilage_thickness, GP_measurements, left_on = 'Sample', right_on = 'Sample')
GP_merge.head()

# %%
ITS_erode_merge = pd.merge(ITS_erode_merge, GP_merge, left_on = 'ID', right_on = 'ID')
ITS_erode_merge.head()

# %%
ITS_erode_merge.to_csv(DATA /'GP_right.txt', sep = '\t')

# %%
ax = sns.barplot(data = ITS_erode_merge, x='Location_Subregion', y='Cart_LAT_thickness', hue='Month', estimator=np.mean, ci = 68, capsize=.2)
ax.legend_.remove()
pairs=[('RF_LAT', 'RF_MED'), ('RF_LAT', 'RT_LAT'), ('RF_LAT', 'RT_MED'),('RF_MED',  'RT_LAT'), ('RF_MED', 'RT_MED'), ('RT_LAT', 'RT_MED')]

annotator = Annotator(ax, pairs, data=ITS_erode_merge, x='Location_Subregion', y='Cart_LAT_thickness')
annotator.configure(test='t-test_paired', text_format='star', loc='outside')
#annotator.apply_and_annotate()

# %% [markdown]
# ## Longitudinal Analyses

# %%
ITS_erode_merge.rm_anova(dv='PR_ratio',
                  within=['Location_Subregion', 'Month'],
                  subject='GP', detailed = False)

# %%
post_hocs = pg.pairwise_ttests(dv='PR_ratio',
                  within=['Location_Subregion', 'Month'],
                  subject='GP', padjust='sidak', data = ITS_erode_merge)
post_hocs

# %%
ITS_erode_merge.rm_anova(dv='rTb_N',
                  within=['Location_Subregion', 'Month'],
                  subject='GP', detailed = False)

# %%
post_hocs = pg.pairwise_ttests(dv='rTb_N',
                  within=['Location_Subregion', 'Month'],
                  subject='GP', padjust='BH', data = ITS_erode_merge)
post_hocs

# %%
ITS_erode_merge.rm_anova(dv='pTb_Th',
                  within=['Location_Subregion', 'Month'],
                  subject='GP', detailed = False)

# %%
post_hocs = pg.pairwise_ttests(dv='pTb_Th',
                  within=['Location_Subregion', 'Month'],
                  subject='GP', padjust='bonferroni', data = ITS_erode_merge)
post_hocs

# %% [markdown]
# ## Cross-sectional Analyses

# %%
PR_model = ols('PR_ratio ~ C(Location_Subregion) + C(Month) + C(Location_Subregion):C(Month)', data=ITS_erode_merge).fit()

sm.stats.anova_lm(PR_model,typ=2)

# %%
sp.posthoc_ttest(ITS_erode_merge, val_col='PR_Ratio', group_col='Month', p_adjust='holm')

# %% [markdown]
# # Plot ITS results - line graphs

# %%
plt.style.use('seaborn-bright')
plt.rcParams["figure.figsize"] = (20,10)
plt.rcParams.update({'font.size': 20}) 
import numpy as np

# %%
ITS_erode_RT_MED["Month"] = ITS_erode_RT_MED["Month"].astype(str)

#hue_order = list(['3', '4', '5'])
#order = ["RF_LAT", "RF_MED", "RT_LAT","RT_MED"]
#order = ["LF_LAT", "LF_MED", "LT_LAT","LT_MED","RF_LAT", "RF_MED", "RT_LAT","RT_MED"]


hue_plot_params = {
    'data': ITS_erode_RT_MED,
    'x': 'Month',
  #  "order": order,
    "hue": "GP_Location_Subregion",
    #"hue_order": "RT_MED"
    #"hue_order": order
}
# Out:
# C:\Users\Teo\AppData\Local\Temp\ipykernel_35152\792182400.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ITS_erode_RT_MED["Month"] = ITS_erode_RT_MED["Month"].astype(str)

# %%
ax = sns.lineplot(**hue_plot_params, y='PR_ratio')

# %%
ax = sns.lineplot(**hue_plot_params, y='BV_TV')

# %%
ax = sns.lineplot(**hue_plot_params, y='pBV_TV')

# %%
ax = sns.lineplot(**hue_plot_params, y='rBV_TV')

# %%
ax = sns.lineplot(**hue_plot_params, y='rTb_N')

# %%
ax = sns.lineplot(**hue_plot_params, y='rTb_Th')

# %%
ax = sns.lineplot(**hue_plot_params, y='pTb_Th')

# %% [markdown]
# # Plot ITS results bar graphs

# %%
plt.style.use('seaborn-muted')
#plt.style.use('dark_background')
#plt.style.use('seaborn-bright')
#plt.style.use('grayscale')
#plt.style.use('seaborn-Greys')

# %%
#plt.rcParams["figure.figsize"] = (5.5, 4)
#plt.rcParams["figure.figsize"] = (16.5,6.2)
plt.rcParams["figure.figsize"] = (20,34)
#plt.rcParams["figure.figsize"] = (12,5)
plt.rcParams.update({'font.size': 40, 'font.weight' : 'bold', 'axes.labelweight': 'bold'}) #, 'title.labelweight': 'bold'})

# %%
ITS_merge_5 = ITS_merge[(ITS_merge.Cohort == 5)]
ITS_merge_5
# Out:
#                                 Filename    BV_TV   pBV_TV   rBV_TV   aBV_TV  \
# 16         E0016710_LF_LAT_ITS_ERODE25;1  0.27561  0.17803  0.09759  0.14013
# 17         E0016710_LF_MED_ITS_ERODE25;1  0.32461  0.20711  0.11751  0.14483
# 18         E0016710_LT_LAT_ITS_ERODE25;1  0.25210  0.10050  0.15160  0.06152
# 19         E0016710_LT_MED_ITS_ERODE25;1  0.32747  0.18915  0.13831  0.13960
# 20         E0016710_RF_LAT_ITS_ERODE25;1  0.26242  0.16130  0.10112  0.14474
# ..                                   ...      ...      ...      ...      ...
# 189            E0017021_RT_MED_ITS_230;1  0.43929  0.33420  0.10509  0.20288
# 190  E0017300_LF_MED_SPLIT1_ERODE5_ITS;1  0.27680  0.19204  0.08476  0.09165
# 191    E0017022_RF_MED_ITS_230_ERODE20;1  0.43072  0.32073  0.11000  0.24102
# 192    E0017023_RT_LAT_ITS_230_ERODE20;1  0.44748  0.30719  0.14030  0.19410
# 193    E0017023_RT_MED_ITS_230_ERODE20;1  0.50391  0.36089  0.14302  0.24150
#
#       pBV_BV   rBV_BV    pTb_N    rTb_N   pTb_Th  ...  PR_num_ratio        ID  \
# 16   0.64593  0.35407  3.11042  3.06447  0.10708  ...      1.014994  E0016710
# 17   0.63801  0.36199  3.25131  3.25771  0.11602  ...      0.998035  E0016710
# 18   0.39865  0.60135  2.71415  3.67674  0.10143  ...      0.738195  E0016710
# 19   0.57762  0.42238  3.35438  3.59596  0.10874  ...      0.932819  E0016710
# 20   0.61467  0.38533  3.10450  3.14380  0.10666  ...      0.987499  E0016710
# ..       ...      ...      ...      ...      ...  ...           ...       ...
# 189  0.76078  0.23922  3.81828  3.18901  0.11428  ...      1.197325  E0017021
# 190  0.69380  0.30620  3.42714  3.17423  0.09670  ...      1.079676  E0017300
# 191  0.74463  0.25537  3.58779  3.08353  0.12152  ...      1.163533  E0017022
# 192  0.68647  0.31353  3.73174  3.38672  0.11349  ...      1.101874  E0017023
# 193  0.71618  0.28382  3.89246  3.40242  0.11930  ...      1.144027  E0017023
#
#      Location_x  Subregion  Location_Subregion     GP  Month  Location_y  \
# 16           LF        LAT              LF_LAT  GP_10      2         NaN
# 17           LF        MED              LF_MED  GP_10      2         NaN
# 18           LT        LAT              LT_LAT  GP_10      2         NaN
# 19           LT        MED              LT_MED  GP_10      2         NaN
# 20           RF        LAT              RF_LAT  GP_10      2         NaN
# ..          ...        ...                 ...    ...    ...         ...
# 189          RT        MED              RT_MED  GP_11      5          RT
# 190          LF        MED              LF_MED  GP_11      5          LF
# 191          RF        MED              RF_MED  GP_12      5          RF
# 192          RT        LAT              RT_LAT  GP_12      5          RT
# 193          RT        MED              RT_MED  GP_12      5          RT
#
#     Cohort GP_Location_Subregion
# 16       5          GP_10_LF_LAT
# 17       5          GP_10_LF_MED
# 18       5          GP_10_LT_LAT
# 19       5          GP_10_LT_MED
# 20       5          GP_10_RF_LAT
# ..     ...                   ...
# 189      5          GP_11_RT_MED
# 190      5          GP_11_LF_MED
# 191      5          GP_12_RF_MED
# 192      5          GP_12_RT_LAT
# 193      5          GP_12_RT_MED
#
# [86 rows x 27 columns]

# %%
ITS_merge["Month"] = ITS_merge["Month"].astype(str)

hue_order = list(['2', '3', '4', '5'])
order = ["RT_LAT","RT_MED"]
#order = ["RF_LAT", "RF_MED", "RT_LAT","RT_MED"]
#order = ["LF_LAT", "LF_MED", "LT_LAT","LT_MED","RF_LAT", "RF_MED", "RT_LAT","RT_MED"]


hue_plot_params = {
    'data': ITS_merge,
    'x': 'Location_Subregion',
    "order": order,
    "hue": "Month",
    "hue_order": hue_order
}

# %%
import seaborn as sns

def ITS_plot(ITS_param, ITS_param_units):
    #ax = sns.barplot(**hue_plot_params, y=ITS_param, estimator=np.mean, ci=68, capsize=.2, errcolor='white') 
    #ax = sns.stripplot(**hue_plot_params, y=ITS_param, color='white', dodge=True)
    
    ax = sns.barplot(**hue_plot_params, y=ITS_param, estimator=np.mean, ci=68, capsize=.15, errcolor='black') #,fill=False)
    ax = sns.swarmplot(**hue_plot_params, y=ITS_param, color='black', size = 14, dodge=True)
    
    ax.set(xlabel = 'Location') #, fontweight=bold)
    ax.set(ylabel = ITS_param_units)
    #ax.set(title = ITS_param) #, fontweight=bold)

    ax.legend_.remove()
    #ax.legend(loc='upper center',ncol=4)
    ax.spines['top'].set_visible(True)
    ax.spines['right'].set_visible(True)

    annotator = Annotator(ax, pairs, **hue_plot_params, y=ITS_param,show_non_significant=False)
    annotator.configure(test='t-test_ind', comparisons_correction='BH', correction_format="replace", text_format='star', color='black', loc='inside',pvalue_thresholds=[[1e-4, "*"], [1e-3, "*"], [1e-2, "*"], [0.05, "*"],[1, ""]])
    annotator.apply_and_annotate()
 
    img_name = str(DATA) + "/ITS_" + ITS_param + ".png"
    plt.tight_layout()

    plt.savefig(img_name, bbox_inches = "tight")

# %%
def ITS_subplots3(ITS_param1, ITS_param2, ITS_param3):
    plt.subplot(1,3,1)
    ITS_plot(ITS_param1)
    plt.xticks(rotation=45, ha='right')
    plt.subplot(1,3,2)
    ITS_plot(ITS_param2)
    plt.xticks(rotation=45, ha='right')
    plt.subplot(1,3,3)
    ITS_plot(ITS_param3)
    plt.xticks(rotation=45, ha='right')
    
    img_name = str(DATA) + "/ITS_subplots.png"
    plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
    plt.savefig(img_name) #, bbox_inches = "tight")

# %%
def ITS_subplots6(ITS_param1, ITS_param_units1, ITS_param2, ITS_param_units2, ITS_param3, ITS_param_units3, ITS_param4, ITS_param_units4, ITS_param5, ITS_param_units5, ITS_param6, ITS_param_units6,):
    plt.subplot(3,2,1)
    ITS_plot(ITS_param1, ITS_param_units1)
    plt.xticks(ha='center')
    plt.subplot(3,2,2)
    ITS_plot(ITS_param2, ITS_param_units2)
    plt.xticks(ha='center')
    plt.subplot(3,2,3)
    ITS_plot(ITS_param3, ITS_param_units3)
    plt.xticks(ha='center')
    plt.subplot(3,2,4)
    ITS_plot(ITS_param4, ITS_param_units4)
    plt.xticks(ha='center')
    plt.subplot(3,2,5)
    ITS_plot(ITS_param5, ITS_param_units5)
    plt.xticks(ha='center')
    plt.subplot(3,2,6)
    ITS_plot(ITS_param6, ITS_param_units6)
    plt.xticks(ha='center')
    
    img_name = str(DATA) + "/ITS_subplots.png"
    plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
    plt.savefig(img_name) #, bbox_inches = "tight")

# %%
def ITS_subplots9(ITS_param1, ITS_param_units1, ITS_param2, ITS_param_units2, ITS_param3, ITS_param_units3, ITS_param4, ITS_param_units4, ITS_param5, ITS_param_units5, ITS_param6, ITS_param_units6,
                 ITS_param7, ITS_param_units7, ITS_param8, ITS_param_units8, ITS_param9, ITS_param_units9):
    plt.subplot(3,3,1)
    ITS_plot(ITS_param1, ITS_param_units1)
    plt.xticks(ha='center')
    plt.subplot(3,3,2)
    ITS_plot(ITS_param2, ITS_param_units2)
    plt.xticks(ha='center')
    plt.subplot(3,3,3)
    ITS_plot(ITS_param3, ITS_param_units3)
    plt.xticks(ha='center')
    plt.subplot(3,3,4)
    ITS_plot(ITS_param4, ITS_param_units4)
    plt.xticks(ha='center')
    plt.subplot(3,3,5)
    ITS_plot(ITS_param5, ITS_param_units5)
    plt.xticks(ha='center')
    plt.subplot(3,3,6)
    ITS_plot(ITS_param6, ITS_param_units6)
    plt.xticks(ha='center')
    plt.subplot(3,3,7)
    TS_plot(ITS_param4, ITS_param_units7)
    plt.xticks(ha='center')
    plt.subplot(3,3,8)
    ITS_plot(ITS_param5, ITS_param_units8)
    plt.xticks(ha='center')
    plt.subplot(3,3,9)
    ITS_plot(ITS_param6, ITS_param_units9)
    plt.xticks(ha='center')
    
    
    img_name = str(DATA) + "/ITS_subplots.png"
    plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
    plt.savefig(img_name) #, bbox_inches = "tight")

# %%
ITS_merge.to_csv(DATA/'ITS_longitudinal_merge.csv',index=False)

# %%
# compare between regions at same time

pairs=[[('2','RF_LAT'), ('2','RF_MED')], [('2','RF_LAT'), ('2','RT_LAT')], [('2','RF_LAT'), ('2','RT_MED')],[('2','RF_MED'), ('2','RT_LAT')],[('2','RF_MED'), ('2','RT_MED')],[('2','RT_LAT'), ('2','RT_MED')],
       [('3','RF_LAT'), ('3','RF_MED')], [('3','RF_LAT'), ('3','RT_LAT')], [('3','RF_LAT'), ('3','RT_MED')],[('3','RF_MED'), ('3','RT_LAT')],[('3','RF_MED'), ('3','RT_MED')],[('3','RT_LAT'), ('3','RT_MED')],
       [('4','RF_LAT'), ('4','RF_MED')], [('4','RF_LAT'), ('4','RT_LAT')], [('4','RF_LAT'), ('4','RT_MED')],[('4','RF_MED'), ('4','RT_LAT')],[('4','RF_MED'), ('4','RT_MED')],[('4','RT_LAT'), ('4','RT_MED')],
       [('5','RF_LAT'), ('5','RF_MED')], [('5','RF_LAT'), ('5','RT_LAT')], [('5','RF_LAT'), ('5','RT_MED')],[('5','RF_MED'), ('5','RT_LAT')],[('5','RF_MED'), ('5','RT_MED')],[('5','RT_LAT'), ('5','RT_MED')]]

# %%
# compare between times at different regions

pairs=[[('RF_LAT','2'), ('RF_LAT','3')], [('RF_LAT','2'), ('RF_LAT','4')], [('RF_LAT','2'), ('RF_LAT','5')],[('RF_LAT','3'), ('RF_LAT','4')],[('RF_LAT','3'), ('RF_LAT','5')],[('RF_LAT','4'), ('RF_LAT','5')],
       [('RF_MED','2'), ('RF_MED','3')], [('RF_MED','2'), ('RF_MED','4')], [('RF_MED','2'), ('RF_MED','5')],[('RF_MED','3'), ('RF_MED','4')],[('RF_MED','3'), ('RF_MED','5')],[('RF_MED','4'), ('RF_MED','5')],
       [('RT_LAT','2'), ('RT_LAT','3')], [('RT_LAT','2'), ('RT_LAT','4')], [('RT_LAT','2'), ('RT_LAT','5')],[('RT_LAT','3'), ('RT_LAT','4')],[('RT_LAT','3'), ('RT_LAT','5')],[('RT_LAT','4'), ('RT_LAT','5')],
       [('RT_MED','2'), ('RT_MED','3')], [('RT_MED','2'), ('RT_MED','4')], [('RT_MED','2'), ('RT_MED','5')],[('RT_MED','3'), ('RT_MED','4')],[('RT_MED','3'), ('RT_MED','5')],[('RT_MED','4'), ('RT_MED','5')]]

# %%
# compare between times at different regions

pairs=[[('RT_LAT','2'), ('RT_LAT','3')], [('RT_LAT','2'), ('RT_LAT','4')], [('RT_LAT','2'), ('RT_LAT','5')],[('RT_LAT','3'), ('RT_LAT','4')],[('RT_LAT','3'), ('RT_LAT','5')],[('RT_LAT','4'), ('RT_LAT','5')],
       [('RT_MED','2'), ('RT_MED','3')], [('RT_MED','2'), ('RT_MED','4')], [('RT_MED','2'), ('RT_MED','5')],[('RT_MED','3'), ('RT_MED','4')],[('RT_MED','3'), ('RT_MED','5')],[('RT_MED','4'), ('RT_MED','5')]]

# %%
pairs=[[('RF_LAT','2'), ('RF_LAT','3')], [('RF_LAT','2'), ('RF_LAT','4')], [('RF_LAT','2'), ('RF_LAT','5')],[('RF_LAT','3'), ('RF_LAT','4')],[('RF_LAT','3'), ('RF_LAT','5')],[('RF_LAT','4'), ('RF_LAT','5')],
       [('RF_MED','2'), ('RF_MED','3')], [('RF_MED','2'), ('RF_MED','4')], [('RF_MED','2'), ('RF_MED','5')],[('RF_MED','3'), ('RF_MED','4')],[('RF_MED','3'), ('RF_MED','5')],[('RF_MED','4'), ('RF_MED','5')],
       [('RT_LAT','2'), ('RT_LAT','3')], [('RT_LAT','2'), ('RT_LAT','4')], [('RT_LAT','2'), ('RT_LAT','5')],[('RT_LAT','3'), ('RT_LAT','4')],[('RT_LAT','3'), ('RT_LAT','5')],[('RT_LAT','4'), ('RT_LAT','5')],
       [('RT_MED','2'), ('RT_MED','3')], [('RT_MED','2'), ('RT_MED','4')], [('RT_MED','2'), ('RT_MED','5')],[('RT_MED','3'), ('RT_MED','4')],[('RT_MED','3'), ('RT_MED','5')],[('RT_MED','4'), ('RT_MED','5')],
       [('LF_LAT','2'), ('LF_LAT','3')], [('LF_LAT','2'), ('LF_LAT','4')], [('LF_LAT','2'), ('LF_LAT','5')],[('LF_LAT','3'), ('LF_LAT','4')],[('LF_LAT','3'), ('LF_LAT','5')],[('LF_LAT','4'), ('LF_LAT','5')],
       [('LF_MED','2'), ('LF_MED','3')], [('LF_MED','2'), ('LF_MED','4')], [('LF_MED','2'), ('LF_MED','5')],[('LF_MED','3'), ('LF_MED','4')],[('LF_MED','3'), ('LF_MED','5')],[('LF_MED','4'), ('LF_MED','5')],
       [('LT_LAT','2'), ('LT_LAT','3')], [('LT_LAT','2'), ('LT_LAT','4')], [('LT_LAT','2'), ('LT_LAT','5')],[('LT_LAT','3'), ('LT_LAT','4')],[('LT_LAT','3'), ('LT_LAT','5')],[('LT_LAT','4'), ('LT_LAT','5')],
       [('LT_MED','2'), ('LT_MED','3')], [('LT_MED','2'), ('LT_MED','4')], [('LT_MED','2'), ('LT_MED','5')],[('LT_MED','3'), ('LT_MED','4')],[('LT_MED','3'), ('LT_MED','5')],[('LT_MED','4'), ('LT_MED','5')]]

# %%
ITS_subplots3('BV_TV','PR_ratio','PR_num_ratio')

# %%
ITS_subplots3('pBV_TV','pTb_N','pTb_Th')

# %%
ITS_subplots3('rBV_TV','rTb_N','rTb_Th')

# %%
ITS_subplots6('BV_TV','BV/TV','PR_ratio','PR Ratio','pBV_TV','pBV/TV','rBV_TV','rBV/TV','pTb_N','pTb.N (1/mm)','rTb_N', 'rTb.N (1/mm)')
# Out:
# D:\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# p-value annotation legend:
#         : p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#        *: 1.00e-03 < p <= 1.00e-02
#        *: 1.00e-04 < p <= 1.00e-03
#        *: p <= 1.00e-04
#
# RT_LAT_2 vs. RT_LAT_3: t-test independent samples with Benjamini-Hochberg correction, P_val:9.641e-05 t=-5.152e+00
# RT_LAT_3 vs. RT_LAT_4: t-test independent samples with Benjamini-Hochberg correction, P_val:3.954e-02 (ns) t=-2.288e+00
# RT_MED_2 vs. RT_MED_3: t-test independent samples with Benjamini-Hochberg correction, P_val:1.123e-03 t=-3.960e+00
# RT_MED_3 vs. RT_MED_4: t-test independent samples with Benjamini-Hochberg correction, P_val:6.868e-03 t=-3.207e+00
# RT_LAT_3 vs. RT_LAT_5: t-test independent samples with Benjamini-Hochberg correction, P_val:6.414e-03 t=-3.432e+00
# RT_LAT_2 vs. RT_LAT_4: t-test independent samples with Benjamini-Hochberg correction, P_val:3.316e-05 t=-6.181e+00
# RT_MED_2 vs. RT_MED_4: t-test independent samples with Benjamini-Hochberg correction, P_val:7.797e-05 t=-5.660e+00
# RT_LAT_2 vs. RT_LAT_5: t-test independent samples with Benjamini-Hochberg correction, P_val:5.799e-05 t=-6.638e+00
# RT_MED_2 vs. RT_MED_5: t-test independent samples with Benjamini-Hochberg correction, P_val:3.702e-03 t=-3.763e+00
# p-value annotation legend:
#         : p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#        *: 1.00e-03 < p <= 1.00e-02
#        *: 1.00e-04 < p <= 1.00e-03
#        *: p <= 1.00e-04
#
# RT_LAT_2 vs. RT_LAT_3: t-test independent samples with Benjamini-Hochberg correction, P_val:2.342e-03 t=-3.611e+00
# RT_MED_2 vs. RT_MED_3: t-test independent samples with Benjamini-Hochberg correction, P_val:2.072e-02 t=-2.566e+00
# RT_MED_3 vs. RT_MED_4: t-test independent samples with Benjamini-Hochberg correction, P_val:4.942e-02 (ns) t=-2.167e+00
# RT_LAT_3 vs. RT_LAT_5: t-test independent samples with Benjamini-Hochberg correction, P_val:2.030e-02 t=-2.755e+00
# RT_MED_3 vs. RT_MED_5: t-test independent samples with Benjamini-Hochberg correction, P_val:2.063e-02 t=-2.746e+00
# RT_LAT_2 vs. RT_LAT_4: t-test independent samples with Benjamini-Hochberg correction, P_val:1.107e-04 t=-5.453e+00
# RT_MED_2 vs. RT_MED_4: t-test independent samples with Benjamini-Hochberg correction, P_val:1.539e-04 t=-5.261e+00
# RT_LAT_2 vs. RT_LAT_5: t-test independent samples with Benjamini-Hochberg correction, P_val:1.220e-04 t=-6.060e+00
# RT_MED_2 vs. RT_MED_5: t-test independent samples with Benjamini-Hochberg correction, P_val:2.117e-04 t=-5.653e+00
# p-value annotation legend:
#         : p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#        *: 1.00e-03 < p <= 1.00e-02
#        *: 1.00e-04 < p <= 1.00e-03
#        *: p <= 1.00e-04
#
# RT_LAT_2 vs. RT_LAT_3: t-test independent samples with Benjamini-Hochberg correction, P_val:3.226e-04 t=-4.558e+00
# RT_MED_2 vs. RT_MED_3: t-test independent samples with Benjamini-Hochberg correction, P_val:2.370e-03 t=-3.606e+00
# RT_MED_3 vs. RT_MED_4: t-test independent samples with Benjamini-Hochberg correction, P_val:3.753e-03 t=-3.522e+00
# RT_LAT_3 vs. RT_LAT_5: t-test independent samples with Benjamini-Hochberg correction, P_val:1.207e-02 t=-3.059e+00
# RT_MED_3 vs. RT_MED_5: t-test independent samples with Benjamini-Hochberg correction, P_val:1.735e-02 t=-2.847e+00
# RT_LAT_2 vs. RT_LAT_4: t-test independent samples with Benjamini-Hochberg correction, P_val:3.451e-05 t=-6.157e+00
# RT_MED_2 vs. RT_MED_4: t-test independent samples with Benjamini-Hochberg correction, P_val:2.246e-05 t=-6.427e+00
# RT_LAT_2 vs. RT_LAT_5: t-test independent samples with Benjamini-Hochberg correction, P_val:1.563e-05 t=-7.744e+00
# RT_MED_2 vs. RT_MED_5: t-test independent samples with Benjamini-Hochberg correction, P_val:6.217e-04 t=-4.902e+00
# D:\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# p-value annotation legend:
#         : p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#        *: 1.00e-03 < p <= 1.00e-02
#        *: 1.00e-04 < p <= 1.00e-03
#        *: p <= 1.00e-04
#
# RT_LAT_2 vs. RT_LAT_4: t-test independent samples with Benjamini-Hochberg correction, P_val:3.952e-03 t=3.495e+00
# RT_LAT_2 vs. RT_LAT_5: t-test independent samples with Benjamini-Hochberg correction, P_val:1.867e-03 t=4.187e+00
# RT_MED_2 vs. RT_MED_5: t-test independent samples with Benjamini-Hochberg correction, P_val:1.498e-02 (ns) t=2.932e+00
# p-value annotation legend:
#         : p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#        *: 1.00e-03 < p <= 1.00e-02
#        *: 1.00e-04 < p <= 1.00e-03
#        *: p <= 1.00e-04
#
# RT_LAT_2 vs. RT_LAT_3: t-test independent samples with Benjamini-Hochberg correction, P_val:3.088e-04 t=-4.579e+00
# RT_MED_2 vs. RT_MED_3: t-test independent samples with Benjamini-Hochberg correction, P_val:3.213e-03 t=-3.462e+00
# RT_LAT_3 vs. RT_LAT_5: t-test independent samples with Benjamini-Hochberg correction, P_val:1.680e-02 t=-2.865e+00
# RT_LAT_2 vs. RT_LAT_4: t-test independent samples with Benjamini-Hochberg correction, P_val:1.304e-04 t=-5.357e+00
# RT_MED_2 vs. RT_MED_4: t-test independent samples with Benjamini-Hochberg correction, P_val:6.223e-04 t=-4.478e+00
# RT_LAT_2 vs. RT_LAT_5: t-test independent samples with Benjamini-Hochberg correction, P_val:5.545e-04 t=-4.979e+00
# RT_MED_2 vs. RT_MED_5: t-test independent samples with Benjamini-Hochberg correction, P_val:2.193e-02 t=-2.710e+00
# p-value annotation legend:
#         : p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#        *: 1.00e-03 < p <= 1.00e-02
#        *: 1.00e-04 < p <= 1.00e-03
#        *: p <= 1.00e-04
#
# RT_LAT_2 vs. RT_LAT_4: t-test independent samples with Benjamini-Hochberg correction, P_val:3.387e-03 t=3.575e+00
# RT_LAT_2 vs. RT_LAT_5: t-test independent samples with Benjamini-Hochberg correction, P_val:1.443e-04 t=5.934e+00
# RT_MED_2 vs. RT_MED_5: t-test independent samples with Benjamini-Hochberg correction, P_val:1.048e-03 t=4.556e+00

# %%
ITS_plot('BV_TV',**hue_plot_params)

# %%
ITS_plot('PR_ratio')
# Out:
# p-value annotation legend:
#         : p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#        *: 1.00e-03 < p <= 1.00e-02
#        *: 1.00e-04 < p <= 1.00e-03
#        *: p <= 1.00e-04
#
# RT_LAT_2 vs. RT_LAT_3: t-test independent samples with Benjamini-Hochberg correction, P_val:2.342e-03 t=-3.611e+00
# RT_MED_2 vs. RT_MED_3: t-test independent samples with Benjamini-Hochberg correction, P_val:2.072e-02 t=-2.566e+00
# RT_MED_3 vs. RT_MED_4: t-test independent samples with Benjamini-Hochberg correction, P_val:4.942e-02 (ns) t=-2.167e+00
# RT_LAT_3 vs. RT_LAT_5: t-test independent samples with Benjamini-Hochberg correction, P_val:2.030e-02 t=-2.755e+00
# RT_MED_3 vs. RT_MED_5: t-test independent samples with Benjamini-Hochberg correction, P_val:2.063e-02 t=-2.746e+00
# RT_LAT_2 vs. RT_LAT_4: t-test independent samples with Benjamini-Hochberg correction, P_val:1.107e-04 t=-5.453e+00
# RT_MED_2 vs. RT_MED_4: t-test independent samples with Benjamini-Hochberg correction, P_val:1.539e-04 t=-5.261e+00
# RT_LAT_2 vs. RT_LAT_5: t-test independent samples with Benjamini-Hochberg correction, P_val:1.220e-04 t=-6.060e+00
# RT_MED_2 vs. RT_MED_5: t-test independent samples with Benjamini-Hochberg correction, P_val:2.117e-04 t=-5.653e+00

# %%
ITS_plot('PR_num_ratio')

# %%
ITS_plot('pBV_TV')

# %%
ITS_plot('rBV_TV')

# %%
ITS_plot('pTb_Th')

# %%
ITS_plot('rTb_Th')

# %%
ITS_plot('pTb_N')

# %%
ITS_plot('rTb_N')
